# %% [markdown]
# # Exploratory data analysis of telco customer data

# %%
# Importing modules
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Loading data to dataframe
df = pd.read_csv('Telco Customer Churn.csv')

# %%
# Checking for null values
df.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# - No missing / null value found

# %%
# Gathering info about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# - The dataset contains data of 7043 customers.
# - TotalCharges column contains numeric values but its data type is object. We shall convert it to numeric.

# %%
# Converting data type of 'TotalCharges' column to float
df['TotalCharges'] = df['TotalCharges'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [5], line 2
#       1 # Converting data type of 'TotalCharges' column to float
# ----> 2 df['TotalCharges'] = df['TotalCharges'].astype(float)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:6534, in NDFrame.astype(self, dtype, copy, errors)
#    6530     results = [ser.astype(dtype, copy=copy) for _, ser in self.items()]
#    6532 else:
#    6533     # else, only a single dtype is given
# -> 6534     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536     return res.__finalize__(self, method="astype")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\managers.py:414, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %% [markdown]
# - Could not convert data type to float. Empty strings (' ') are present which can't be converted to float.

# %%
# Counting the no. of empty string values
count = 0
for i in df['TotalCharges']:
    if i ==' ':
        count+=1
print(count)
# Out:
# 11

# %% [markdown]
# - There are 11 out of 7043 rows where a value is missing. As it is a small number we can remove these rows as there will not be any major impact on the analysis.

# %%
# Dropping rows containing empty strings
df = df.replace(' ', pd.NA).dropna()

# %%
# Converting data type of 'TotalCharges' column to float
df['TotalCharges'] = df['TotalCharges'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7032 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7032 non-null   object
#  1   gender            7032 non-null   object
#  2   SeniorCitizen     7032 non-null   int64
#  3   Partner           7032 non-null   object
#  4   Dependents        7032 non-null   object
#  5   tenure            7032 non-null   int64
#  6   PhoneService      7032 non-null   object
#  7   MultipleLines     7032 non-null   object
#  8   InternetService   7032 non-null   object
#  9   OnlineSecurity    7032 non-null   object
#  10  OnlineBackup      7032 non-null   object
#  11  DeviceProtection  7032 non-null   object
#  12  TechSupport       7032 non-null   object
#  13  StreamingTV       7032 non-null   object
#  14  StreamingMovies   7032 non-null   object
#  15  Contract          7032 non-null   object
# ...

# %% [markdown]
# - TotalCharges has been converted to float type.

# %%
# Checking for duplicate data
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# - No duplicate row found.

# %%
# Displaying first 10 rows of dataframe to know more about the dataset
df.head(10)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
# 5  9305-CDSKC  Female              0      No         No       8          Yes
# 6  1452-KIOVK    Male              0      No        Yes      22          Yes
# 7  6713-OKOMC  Female              0      No         No      10           No
# 8  7892-POOKP  Female              0     Yes         No      28          Yes
# 9  6388-TABGU    Male              0      No        Yes      62          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# ...

# %% [markdown]
# - We can drop 'customerID' and 'TotalCharges' columns as these don't seem to serve any purpose in analysis.

# %%
# Dropping customerID and TotalCharges columns
df = df.drop(['customerID','TotalCharges'], axis=1)

# %%
# Description of data
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7032.000000  7032.000000     7032.000000
# mean        0.162400    32.421786       64.798208
# std         0.368844    24.545260       30.085974
# min         0.000000     1.000000       18.250000
# 25%         0.000000     9.000000       35.587500
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.862500
# max         1.000000    72.000000      118.750000

# %% [markdown]
# - 16.2% of all customers are senior citizens.
# - Average tenure of a customer is 32.4 months and max tenure is 72 months.
# - Average monthly charge paid by customers is ```$64.76```. Min paid charge is ```$18.25``` while max is ```$118.75```.

# %% [markdown]
# ## Outlier Detection:
# Outliers are the data points which are located unusually far from rest of the data.

# %% [markdown]
# ### For categorical data:
# Outliers in categorical data are the categories which have very few datapoints. For this, we can use bar charts to see the data divided among different categories.

# %%
# For gender
df['gender'].value_counts().plot.bar(figsize=(3,3))
# Out:
# <Axes: xlabel='gender'>

# %%
# For SeniorCitizen
df['SeniorCitizen'].value_counts().plot.bar(figsize=(3,3))
# Out:
# <Axes: xlabel='SeniorCitizen'>

# %%
# For Partner
df['Partner'].value_counts().plot.bar(figsize=(3,3))
# Out:
# <Axes: xlabel='Partner'>

# %%
# For Dependents
df['Dependents'].value_counts().plot.bar(figsize=(3,3))
# Out:
# <Axes: xlabel='Dependents'>

# %%
# For PhoneService
df['PhoneService'].value_counts().plot.bar(figsize=(3,3))
# Out:
# <Axes: xlabel='PhoneService'>

# %%
# For MultipleLines
df['MultipleLines'].value_counts().plot.bar(figsize=(3,3))
# Out:
# <Axes: xlabel='MultipleLines'>

# %%
# For InternetService
df['InternetService'].value_counts().plot.bar(figsize=(3,3))
# Out:
# <Axes: xlabel='InternetService'>

# %%
# For OnlineSecurity
df['OnlineSecurity'].value_counts().plot.bar(figsize=(3,3))
# Out:
# <Axes: xlabel='OnlineSecurity'>

# %%
# For OnlineBackup
df['OnlineBackup'].value_counts().plot.bar(figsize=(3,3))
# Out:
# <Axes: xlabel='OnlineBackup'>

# %%
# For DeviceProtection
df['DeviceProtection'].value_counts().plot.bar(figsize=(3,3))
# Out:
# <Axes: xlabel='DeviceProtection'>

# %%
# For TechSupport
df['TechSupport'].value_counts().plot.bar(figsize=(3,3))
# Out:
# <Axes: xlabel='TechSupport'>

# %%
# For StreamingTV
df['StreamingTV'].value_counts().plot.bar(figsize=(3,3))
# Out:
# <Axes: xlabel='StreamingTV'>

# %%
# For StreamingMovies
df['StreamingMovies'].value_counts().plot.bar(figsize=(3,3))
# Out:
# <Axes: xlabel='StreamingMovies'>

# %%
# For Contract
df['Contract'].value_counts().plot.bar(figsize=(3,3))
# Out:
# <Axes: xlabel='Contract'>

# %%
# For PaperlessBilling
df['PaperlessBilling'].value_counts().plot.bar(figsize=(3,3))
# Out:
# <Axes: xlabel='PaperlessBilling'>

# %%
# For PaymentMethod
df['PaymentMethod'].value_counts().plot.bar(figsize=(3,3))
# Out:
# <Axes: xlabel='PaymentMethod'>

# %%
# For Churn
df['Churn'].value_counts().plot.bar(figsize=(3,3))
# Out:
# <Axes: xlabel='Churn'>

# %% [markdown]
# - From above plots we can see that all the categories in each variable consists of considerable number of customers. No category can be considered as an outlier.

# %% [markdown]
# ### For numerical data:
# Outliers can be detected using scatterplot, boxplot, etc.

# %%
# Description of data
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7032.000000  7032.000000     7032.000000
# mean        0.162400    32.421786       64.798208
# std         0.368844    24.545260       30.085974
# min         0.000000     1.000000       18.250000
# 25%         0.000000     9.000000       35.587500
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.862500
# max         1.000000    72.000000      118.750000

# %% [markdown]
# - From the info above an outlier would be a datapoint that is either smaller than Q$_1$ - 1.5 * IQR or greater than Q$_3$ + 1.5 * IQR.
# - For tenure, an outlier would be a value < - 60 or > 124
# - For MonthlyCharges, an outlier would be a value < - 45.96 or > 171.4
# * Q$_1$ = 25 %
# * Q$_3$ = 75 %
# * IQR(Interquartile range) = Q$_3$ - Q$_1$

# %%
# Plotting numerical data to find outliers
df.plot.box(column='tenure', figsize=(3,3))
df.plot.box(column='MonthlyCharges', figsize=(3,3))
# Out:
# <Axes: >

# %% [markdown]
# - From the plots above we can see that no data points can be considered as outliers.
# - So no outliers are present in the dataset.

# %% [markdown]
# ## Finding relationship between churn rate and various variables

# %% [markdown]
# - Churn rate is an important factor an organization should focus on as it is directly related to customer satisfaction and revenue generation.
# - Churn rate = (No. of customers who have churned * 100) / Total no. customers
# - The column 'Churn' here tells us about the customers who have not renewed their contracts.

# %%
df['Churn'].value_counts().plot.pie(autopct = '%1.2f%%', title = 'Churn vs Non-churn customers',label = '', figsize=(3,3))
# Out:
# <Axes: title={'center': 'Churn vs Non-churn customers'}>

# %% [markdown]
# - Overall churn rate is 26.58 which is quite high.

# %%
# Converting data type of 'Churn' column from textual to numeric data
df['Churn'] = df['Churn'].map({'Yes':1, 'No':0})

# %% [markdown]
# ### Churn rate vs customer information

# %%
# Finding churn rate of each gender
df.groupby(['gender']).sum().plot(kind='pie', y='Churn', autopct='%1.2f%%', title = 'Gender(Churn)', label = '', figsize=(3,3))
# Out:
# <Axes: title={'center': 'Gender(Churn)'}>

# %% [markdown]
# - Churn rate of both the genders is almost equal.

# %%
# Converting data type of 'SeniorCitizen' column from numeric to textual data
df['SeniorCitizen'] = df['SeniorCitizen'].map({1:'Yes', 0:'No'})

# %%
# Finding churn rate wrt senior citizenship
df.groupby(['SeniorCitizen']).sum().plot(kind='pie', y='Churn', autopct='%1.2f%%', title = 'Senior Citizen(Churn)', label = '', figsize=(3,3))
# Out:
# <Axes: title={'center': 'Senior Citizen(Churn)'}>

# %% [markdown]
# - Around 74.5 % of customers who churned are of age < 60.

# %%
# Finding churn rate wrt partner
df.groupby(['Partner']).sum().plot(kind='pie', y='Churn', autopct='%1.2f%%', title = 'Partner(Churn)', label = '', figsize=(3,3))
# Out:
# <Axes: title={'center': 'Partner(Churn)'}>

# %% [markdown]
# - Around 64.2 % of churned customers don't have partners.

# %%
# Finding churn rate wrt dependents
df.groupby(['Dependents']).sum().plot(kind='pie', y='Churn', autopct='%1.2f%%', title = 'Dependents(Churn)', label = '', figsize=(3,3))
# Out:
# <Axes: title={'center': 'Dependents(Churn)'}>

# %% [markdown]
# - Around 82.5 % of churned customers don't have dependents.

# %% [markdown]
# From the above plots we can see that:
# - Gender is not playing any role in churn rate.
# - While customers who are of age < 60 or customers who don't have partners or dependents tend to churn more.

# %% [markdown]
# ### Sevices vs Churn rate

# %%
# Finding churn rate wrt PhoneService
df.groupby(['PhoneService']).sum().plot(kind='pie', y='Churn', autopct='%1.2f%%', title = 'Phone Service(Churn)', label = '')
# Out:
# <Axes: title={'center': 'Phone Service(Churn)'}>

# %%
# Finding churn rate wrt MultipleLines
df.groupby(['MultipleLines']).sum().plot(kind='pie', y='Churn', autopct='%1.2f%%', title = 'Multiple Lines(Churn)', label = '')
# Out:
# <Axes: title={'center': 'Multiple Lines(Churn)'}>

# %%
# Finding churn rate wrt InternetService
df.groupby(['InternetService']).sum().plot(kind='pie', y='Churn', autopct='%1.2f%%', title = 'Internet Service(Churn)', label = '')
# Out:
# <Axes: title={'center': 'Internet Service(Churn)'}>

# %%
# Finding churn rate wrt StreamingTV
df.groupby(['StreamingTV']).sum().plot(kind='pie', y='Churn', autopct='%1.2f%%', label = '', title = 'Streaming TV(Churn)')
# Out:
# <Axes: title={'center': 'Streaming TV(Churn)'}>

# %%
# Finding churn rate wrt StreamingMovies
df.groupby(['StreamingMovies']).sum().plot(kind='pie', y='Churn', autopct='%1.2f%%', title = 'Streaming Movies(Churn)', label = '')
# Out:
# <Axes: title={'center': 'Streaming Movies(Churn)'}>

# %% [markdown]
# - Churn rate of customers who don't have phone service is very low. But that is because very less customers are there who have not opted for phone service.
# - Customers who have opted for fiber optic cable churn much more than customers who have opted for DSL.

# %% [markdown]
# ### Support services vs Churn

# %%
# Finding churn rate wrt OnlineSecurity
df.groupby(['OnlineSecurity']).sum().plot(kind='pie', y='Churn', autopct='%1.2f%%', title = 'Online Security(Churn)', label = '')
# Out:
# <Axes: title={'center': 'Online Security(Churn)'}>

# %%
# Finding churn rate wrt OnlineBackup
df.groupby(['OnlineBackup']).sum().plot(kind='pie', y='Churn', autopct='%1.2f%%', title = 'Online Backup(Churn)', label = '')
# Out:
# <Axes: title={'center': 'Online Backup(Churn)'}>

# %%
# Finding churn rate wrt DeviceProtection
df.groupby(['DeviceProtection']).sum().plot(kind='pie', y='Churn', autopct='%1.2f%%', title = 'Device Protection(Churn)', label = '')
# Out:
# <Axes: title={'center': 'Device Protection(Churn)'}>

# %%
# Finding churn rate wrt TechSupport
df.groupby(['TechSupport']).sum().plot(kind='pie', y='Churn', autopct='%1.2f%%', title = 'TechSupport(Churn)', label = '')
# Out:
# <Axes: title={'center': 'TechSupport(Churn)'}>

# %% [markdown]
# - It is clear from above charts that churn rate of customers who have not opted for support services is much more than who have opted for the support services.

# %% [markdown]
# ### Payment Details vs Churn

# %%
# Finding churn rate wrt Contract
df.groupby(['Contract']).sum().plot(kind='pie', y='Churn', autopct='%1.2f%%', title = 'Contract(Churn)', label = '')
# Out:
# <Axes: title={'center': 'Contract(Churn)'}>

# %%
# Finding churn rate wrt PaperlessBilling
df.groupby(['PaperlessBilling']).sum().plot(kind='pie', y='Churn', autopct='%1.2f%%', title = 'Paperless Billing(Churn)', label = '')
# Out:
# <Axes: title={'center': 'Paperless Billing(Churn)'}>

# %%
# Finding churn rate wrt PaymentMethod
df.groupby(['PaymentMethod']).sum().plot(kind='pie', y='Churn', autopct='%1.2f%%', title = 'Payment Method(Churn)', label = '')
# Out:
# <Axes: title={'center': 'Payment Method(Churn)'}>

# %% [markdown]
# - Customers who buy month-to-month contract tend to churn more.
# - Churn rate of customers who opt for paperless billing is very high.
# - Churn rate of customers who prefer electronic check is higher than others.

# %%
# Monthlyrate vs churn, tenure vs churn
